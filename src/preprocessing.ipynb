# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'C:\Users\sdash1\Desktop\OMM-TB\pandas_df2.csv')
# Out:
# C:\Users\sdash1\AppData\Local\Temp\2\ipykernel_20944\2617943635.py:1: DtypeWarning: Columns (9,14,16,17,19,20,25,26) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r'C:\Users\sdash1\Desktop\OMM-TB\pandas_df2.csv')

# %%
df2 = df.head(10).copy()
df2
# Out:
#    Unnamed: 0                                               Name  Product_ID  \
# 0           1                  9001422279 - Lens Head Screw M4x8  MAT_928319
# 1           2      9001730689 - CP body laser printed WT45HV14FR  MAT_928320
# 2           3          9001730699 - USER MA. SE (WT45HV14FR), FR  MAT_928323
# 3           4  9001731054 - fascia panel GV650A.UC Int  White...  MAT_928324
# 4           5  9001762412 - Cable Harness operat. EE 590  SP....  MAT_928325
# 5           6  9001762413 - Cable Harness operat. EE740mm SP....  MAT_928326
# 6           7                     9001766218 - WIRE YELLOW-GREEN  MAT_928327
# 7           8                     9001766289 - WIRE YELLOW-GREEN  MAT_928329
# 8           9                     9001766290 - WIRE YELLOW-GREEN  MAT_928331
# 9          10                5090464588 - DOUGH HOOK MUM4 COMPL.  MAT_928333
#
#   Product_UserTypeID AT_MaraBshmCax3D  AT_MaraNtgew  AT_MaraVolum    AT_SAPID  \
# 0           Material   60100004395930         1.300           0.0  9001422279
# 1           Material              NaN         0.318           0.0  9001730689
# 2           Material              NaN         0.020           0.0  9001730699
# 3           Material   60100007114130         0.000           0.0  9001731054
# 4           Material   60100008886908        26.800           0.0  9001762412
# 5           Material   60100008886908        28.700           0.0  9001762413
# 6           Material              NaN         0.000           0.0  9001766218
# 7           Material              NaN         0.000           0.0  9001766289
# 8           Material              NaN         0.000           0.0  9001766290
# 9           Material   50910332140077         0.049           0.0  5090464588
#
#                         AT_MaraMatkl         AT_MaraNumtp  ...  \
# 0           H002 - Customized screws                  NaN  ...
# 1    R239 - xxx - do not use anymore  prefabricated parts  ...
# 2  X810 - Printed material (general)                  NaN  ...
# 3    R250 - Injected parts (general)                  NaN  ...
# 4             L592 - IDC+IDC jumpers                  NaN  ...
# 5             L592 - IDC+IDC jumpers                  NaN  ...
# 6                         01 - Dummy                  NaN  ...
# 7                         01 - Dummy                  NaN  ...
# 8                         01 - Dummy                  NaN  ...
# 9      H73S - Spare Parts Wire goods                  NaN  ...
#
#                       AT_MaraLabor  AT_MaraExtwg AT_MaraBismt AT_MaraMeins  \
# 0     H10 - FCGB  Inserra, Bortolo           NaN   5750172759     piece(s)
# 1        WD0 - FLCD  Default (FDW)           NaN   9001452855     piece(s)
# 2        WD0 - FLCD  Default (FDW)           NaN   9001452871     piece(s)
# 3     G8A - FDG Neukirchner,Daniel           NaN   8001186041     piece(s)
# 4  VBI - FCGB  Schuhmacher, Jochen           NaN          NaN     piece(s)
# 5  VBI - FCGB  Schuhmacher, Jochen           NaN          NaN     piece(s)
# 6      H4W - FCGL  Schmitt, Benoit           NaN    AJ00-0380     piece(s)
# 7      H4W - FCGL  Schmitt, Benoit           NaN   AJ00-0130A     piece(s)
# 8      H4W - FCGL  Schmitt, Benoit           NaN   AJ00-0130B     piece(s)
# 9               CS0 - FNE  default           NaN       427857     piece(s)
#
#                                         AT_MaraMtart   AT_MaraGroes  \
# 0            Materials which are externally procured            NaN
# 1  Materials which can be potentially produced in...            NaN
# 2  Materials which can be potentially produced in...            NaN
# 3  Materials which can be potentially produced in...            NaN
# 4            Materials which are externally procured       L  590MM
# 5            Materials which are externally procured       L  740MM
# 6  Materials which can be potentially produced in...            NaN
# 7  Materials which can be potentially produced in...            NaN
# 8  Materials which can be potentially produced in...            NaN
# 9  Materials which can be potentially produced in...  S33 2 2 6 250
#
#   AT_LeadingSystem AT_MaraNtgew_UnitID AT_MaraVolum_UnitID AT_MaraBrgew_UnitID
# 0              SAP      unece.unit.GRM      unece.unit.DMQ      unece.unit.GRM
# 1              SAP      unece.unit.KGM      unece.unit.CMQ      unece.unit.KGM
# 2              SAP      unece.unit.KGM      unece.unit.CMQ      unece.unit.KGM
# 3              SAP      unece.unit.GRM      unece.unit.CMQ      unece.unit.GRM
# 4              SAP      unece.unit.GRM      unece.unit.DMQ      unece.unit.GRM
# 5              SAP      unece.unit.GRM      unece.unit.DMQ      unece.unit.GRM
# 6              SAP      unece.unit.KGM      unece.unit.CMQ      unece.unit.KGM
# 7              SAP      unece.unit.KGM      unece.unit.CMQ      unece.unit.KGM
# 8              SAP      unece.unit.KGM      unece.unit.CMQ      unece.unit.KGM
# 9              SAP      unece.unit.KGM      unece.unit.CMQ      unece.unit.KGM
#
# [10 rows x 34 columns]

# %% [markdown]
# Start code from here

# %%
# all preprocessing imports

import re
import nltk
import string
from nltk.corpus import stopwords
from wordcloud import WordCloud, STOPWORDS

# set Stopwords, add custom words/dictionary eventually
stopwords = set(STOPWORDS)
stopwords.update(["nan"])

def heavy_text_clean(x):
    # first lowercase everything
    x = x.lower()
    
    # further work on removing stopwords necessary, not working right now
    #x = ' '.join([word for word in x.split(' ') if word not in stopwords])
    
    # remove unicode characters
    x = x.encode('ascii', 'ignore').decode()
    
    # remove links
    x = re.sub(r'https*\S+', ' ', x)
    x = re.sub(r'http*\S+', ' ', x)
    
    # remove @ symbols and hashtags
    x = re.sub(r'@\S', '', x)
    x = re.sub(r'#\S+', ' ', x)
    
    # remove whitespaces
    x = re.sub(r'\'\w+', '', x)
    x = re.sub('[%s]' % re.escape(string.punctuation), ' ', x)
    
    x = re.sub(r'\w*\d+\w*', '', x)
    
    x = re.sub(r'\s{2,}', ' ', x)
    
    x = re.sub(r'\s[^\w\s]\s', '', x)
    
    # remove single letters and numbers surrounded by space
    x = re.sub(r'\s[a-z]\s|\s[0-9]\s', ' ', x)
    
    return x

# %%
# prepare dataframes

# join all columns into one
df2['text'] = df2.astype(str).agg(' '.join, axis=1)

df2 = df2.iloc[:,-1:]
df3 = df2.text.apply(heavy_text_clean)

# %%
display(df2.astype(str).text, df3)
# Out:
# 0    1 9001422279 - Lens Head Screw M4x8 MAT_928319...
# 1    2 9001730689 - CP body laser printed WT45HV14F...
# 2    3 9001730699 - USER MA. SE (WT45HV14FR), FR MA...
# 3    4 9001731054 - fascia panel GV650A.UC Int  Whi...
# 4    5 9001762412 - Cable Harness operat. EE 590  S...
# 5    6 9001762413 - Cable Harness operat. EE740mm S...
# 6    7 9001766218 - WIRE YELLOW-GREEN MAT_928327 Ma...
# 7    8 9001766289 - WIRE YELLOW-GREEN MAT_928329 Ma...
# 8    9 9001766290 - WIRE YELLOW-GREEN MAT_928331 Ma...
# 9    10 5090464588 - DOUGH HOOK MUM4 COMPL. MAT_928...
# Name: text, dtype: object
# 0     lens head screw mat material customized screw...
# 1     cp body laser printed mat material nan xxx do...
# 2     user ma se fr mat material nan printed materi...
# 3     fascia panel uc int white mat material inject...
# 4     cable harness operat ee sp mat material idc i...
# 5     cable harness operat sp mat material idc idc ...
# 6     wire yellow green mat material nan dummy nan ...
# 7     wire yellow green mat material nan dummy nan ...
# 8     wire yellow green mat material nan dummy nan ...
# 9     dough hook compl mat material spare parts wir...
# Name: text, dtype: object

# %%
from sentence_transformers import SentenceTransformer, util
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

def similarity_scores(df):
    #df: dataframe needs to have one column only
    
    #All-round model tuned for many use-cases. Trained on a large and diverse dataset of over 1 billion training pairs
    model = SentenceTransformer('all-mpnet-base-v2')
    
    #Our sentences we like to encode
    sentences = list(df.astype(str))
    
    #Encode all sentences
    sentence_embeddings = model.encode(sentences)
    
    #init output matrix
    scores = np.zeros((sentence_embeddings.shape[0], sentence_embeddings.shape[0]))
    
    for i in range(sentence_embeddings.shape[0]):
        #Compute cosine similarity between all pairs
        scores[i, :] = cosine_similarity([sentence_embeddings[i]], sentence_embeddings)[0]
        
    return scores

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# calculate similarity scores of dataframe.text
scores = similarity_scores(df2.text) #no cleaning 
scores_pre = similarity_scores(df3) #heavy cleaning

# find min, max values from similarity matrix for plotting
vmin = min(scores.min(), scores_pre.min())
vmax = max(scores.max(), scores_pre.max())

# set subplots layout
fig, axs = plt.subplots(ncols=4, width_ratios=[10,10,0.5,10], figsize=(20, 5))

# create subplots
sns.heatmap(scores, annot=True, cbar=False, ax=axs[0])
sns.heatmap(scores_pre, annot=True, yticklabels=False, cbar=False, ax=axs[1])
sns.heatmap(abs(scores-scores_pre), yticklabels=False, cbar=False, ax=axs[3], cmap="Greys")

# add colorbar
fig.colorbar(axs[1].collections[0], cax=axs[2])

# plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [13], in <cell line: 15>()
#      12 vmax = max(scores.max(), scores_pre.max())
#      14 # set subplots layout
# ---> 15 fig, axs = plt.subplots(ncols=4, width_ratios=[10,10,0.5,10], figsize=(20, 5))
#      17 # create subplots
#      18 sns.heatmap(scores, annot=True, cbar=False, ax=axs[0])
#
# File ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py:1434, in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1300 def subplots(nrows=1, ncols=1, *, sharex=False, sharey=False, squeeze=True,
#    1301              subplot_kw=None, gridspec_kw=None, **fig_kw):
#    1302     """
#    1303     Create a figure and a set of subplots.
#    1304
#    (...)
#    1432
#    1433     """
# -> 1434     fig = figure(**fig_kw)
#    1435     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1436                        squeeze=squeeze, subplot_kw=subplot_kw,
#    1437                        gridspec_kw=gridspec_kw)
#    1438     return fig, axs
#
# File ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py:787, in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#     778 if len(allnums) == max_open_warning >= 1:
#     779     _api.warn_external(
#     780         f"More than {max_open_warning} figures have been opened. "
#     781         f"Figures created through the pyplot interface "
#    (...)
#     784         f"warning, see the rcParam `figure.max_open_warning`).",
#     785         RuntimeWarning)
# --> 787 manager = new_figure_manager(
#     788     num, figsize=figsize, dpi=dpi,
#     789     facecolor=facecolor, edgecolor=edgecolor, frameon=frameon,
#     790     FigureClass=FigureClass, **kwargs)
#     791 fig = manager.canvas.figure
#     792 if fig_label:
#
# File ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py:306, in new_figure_manager(*args, **kwargs)
#     304 """Create a new figure manager instance."""
#     305 _warn_if_gui_out_of_main_thread()
# --> 306 return _backend_mod.new_figure_manager(*args, **kwargs)
#
# File ~\Anaconda3\lib\site-packages\matplotlib\backend_bases.py:3493, in _Backend.new_figure_manager(cls, num, *args, **kwargs)
#    3491 from matplotlib.figure import Figure
#    3492 fig_cls = kwargs.pop('FigureClass', Figure)
# -> 3493 fig = fig_cls(*args, **kwargs)
#    3494 return cls.new_figure_manager_given_figure(num, fig)
#
# File ~\Anaconda3\lib\site-packages\matplotlib\figure.py:2238, in Figure.__init__(self, figsize, dpi, facecolor, edgecolor, linewidth, frameon, subplotpars, tight_layout, constrained_layout, layout, **kwargs)
#    2154 def __init__(self,
#    2155              figsize=None,
#    2156              dpi=None,
#    (...)
#    2166              **kwargs
#    2167              ):
#    2168     """
#    2169     Parameters
#    2170     ----------
#    (...)
#    2236         %(Figure:kwdoc)s
#    2237     """
# -> 2238     super().__init__(**kwargs)
#    2240     if layout is not None:
#    2241         if tight_layout is not None:
#
# File ~\Anaconda3\lib\site-packages\matplotlib\figure.py:216, in FigureBase.__init__(self, **kwargs)
#     214 self.stale = True
#     215 self.suppressComposite = None
# --> 216 self.set(**kwargs)
#
# File ~\Anaconda3\lib\site-packages\matplotlib\artist.py:116, in Artist.__init_subclass__.<locals>.<lambda>(self, **kwargs)
#     108 if not hasattr(cls.set, '_autogenerated_signature'):
#     109     # Don't overwrite cls.set if the subclass or one of its parents
#     110     # has defined a set method set itself.
#     111     # If there was no explicit definition, cls.set is inherited from
#     112     # the hierarchy of auto-generated set methods, which hold the
#     113     # flag _autogenerated_signature.
#     114     return
# --> 116 cls.set = lambda self, **kwargs: Artist.set(self, **kwargs)
#     117 cls.set.__name__ = "set"
#     118 cls.set.__qualname__ = f"{cls.__qualname__}.set"
#
# File ~\Anaconda3\lib\site-packages\matplotlib\artist.py:1164, in Artist.set(self, **kwargs)
#    1159 def set(self, **kwargs):
#    1160     # docstring and signature are auto-generated via
#    1161     # Artist._update_set_signature_and_docstring() at the end of the
#    1162     # module.
#    1163     kwargs = cbook.normalize_kwargs(kwargs, self)
# -> 1164     return self.update(kwargs)
#
# File ~\Anaconda3\lib\site-packages\matplotlib\artist.py:1064, in Artist.update(self, props)
#    1062             func = getattr(self, f"set_{k}", None)
#    1063             if not callable(func):
# -> 1064                 raise AttributeError(f"{type(self).__name__!r} object "
#    1065                                      f"has no property {k!r}")
#    1066             ret.append(func(v))
#    1067 if ret:
#
# AttributeError: 'Figure' object has no property 'width_ratios'
